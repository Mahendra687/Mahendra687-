# %% [markdown]
# **Mahendra Pratap Singh** <img align="right" width="105" height="105" src="https://avatars.githubusercontent.com/u/55095422?v=4">
# >  **Address:** O Block 117/178 Geeta Nagar, Kanpur, U.P 208024.
# >  **Tel:** 7905308265 | **Email:** mahend58_sit@jnu.ac.in |
# [GitHub](https://github.com/Mahendra687)
#
# **Mini Capstone Projects on Data Science:**
# > * Build a machine learnig model to improve the performance across the business funnel of advertisers using various regression techniques on the top of DeltaX dataset | [Notebook](https://github.com/Mahendra687/Summer-School/blob/main/Project/capstone-project.ipynb)
# > * RNASeq Analysis | [Notebook1](https://github.com/Mahendra687/RNA-Seq-data-analysis/blob/main/mirRNA/miRNA_DESeqAnalysis.ipynb)
# > * BetaCoronavirus Genotyping for Armenian WGS isolate | [DOI](https://zenodo.org/record/5825996#.ZBRCr45Bze1)
# > * Build a classification decision tree using the penguins dataset
# > * Build a ensemble methods over simple models:decision tree and linear model on california housing dataset
# > * Tune a random forest classifier on the adult census dataset
# > * Biological image analysis using python [scikit-Image](https://scikit-image.org/) processing library
# > * Benchmarking on genomic variant calling using SomaticSniper and GATK:MuTect packages
#
# **Academic Thesis Projects:**
# > * Sequence and Evolutionary Analysis Of miR2118 and miR2275 in Sorghum, supervised by
# Prof. Rita Sharma at SCIS, JNU
# > * Comparative Study Of Triticum Urartu Genome, supervised by Dr Mamta Sagar at UIET,
# CSJM University
# > * Understanding The Lung Cancer Using Bioinformatics, supervised by Dr Mukesh Kumar
# Awasthi at AKS University
#
# **Data science skills:**
# > * Programming: Python and R
# > * Libraries and Framework: pandas, numpy, matplotlib, seaborn, scikit-learn, scikit-image tensorflow/keras, , opencv, and Streamlit etc.
# > * Machine Learning and Deep Learning algorithms: Regression, Classification, Clustering, Dimensionality Reduction,  Deep Learning:Convolutional Neural Networks and Image Segmentation-Classification
# > * OS: Linux-Ubuntu, macOS and LibreOffice
# > * Cloud platform: AWS-Batch and Google Cloud Platform (GCP)
# > * Version Control: Git and GitHub
# > * Container: Docker and Airflow
# > * Notebook:  Jupyter Notebook and Colab
# > * Databases: SQLite, and PostgreSQL
# > * NGS data analysis: **Quality control** FastQC, Fastx, FastP, MutliQC, NGS-QC and Trimmomatic | **Aligner**: Bowtie, TopHat2, HISAT2, Genome Mapper, Minimap2 and STAR | **Assembler**: Velvet, SPAdes ABySS and StringTie | **Read Counter**: STARcount and featureCounts | **Bioconductor**: DESeq2 and edgeR
#
# **Certifications Training:**
# > * Machine learning in Python with scikit-learn from The ScikitLearnMooc, May 2022 | [Certificate](https://user-images.githubusercontent.com/97247515/169219726-19d7ea0b-ff27-445c-ae92-a6b9326d0ab7.jpeg)
# > * Image Analysis Methods for Biologists from The Univerisity of Nottingham, Feb 2022 | [Certificate](https://user-images.githubusercontent.com/97247515/170100171-3ede0a57-8d97-45a1-8ee7-053cbff808e1.png)
# > * How to Customise GitHub Profile from EddieHub Course, Feb 2022 | [Certificate](https://github.com/Mahendra687/Coding-with-Git/files/8830040/Github.pdf)
# > * AI for Healthcare from The University of Manchester Jan 2022 | [Certificate](https://user-images.githubusercontent.com/97247515/170098883-68dea3ae-2af0-45f5-b823-ea1e76e26ed5.png)
# > * The Power of Data in Health Care from University of Strathclyde, Jan 2022 | [Certificate](https://user-images.githubusercontent.com/97247515/170097248-7dd0e4dd-97d0-4293-bd15-4df2159b1082.png)
# > * Applied Data Science from Institute of Coding Feb 2021 | [Certificate](https://user-images.githubusercontent.com/97247515/170094566-9b883e0d-ddd5-4d0c-9303-12c8f57bf5d0.png)
# > * Descriptive Statistics with R Software from the NPTEL, Feb 2019 | [Certificate](https://user-images.githubusercontent.com/97247515/170091717-587283e7-b924-437b-9ac9-85cb262176e1.png)
# > * Learn to Code for Data Analysis from The Open University, Nov 2018 | [Certificate](https://user-images.githubusercontent.com/97247515/170089235-ddcf7994-d26f-49e3-bfc9-cebe32dd7dd2.png)
# > * BioInformatics: Algorithms and Applications from IIT, Madras, Apr 2018 | [Certificate](https://user-images.githubusercontent.com/97247515/170574476-bb5dc210-d0f7-4c7b-adad-31a8dd9ad0d1.png)
#
# **Summer  School:**
# > * Data Analytics Internship at Start-Tech Academy, May 2022 | [Certificate](https://user-images.githubusercontent.com/97247515/170182814-10cede63-dd2f-4997-9d18-51e61890215d.png)
# > * Next Generation Sequencing Data Analysis from National Genomics Core-CDFD,Hyderabad Jun 2021 | [Certificate](https://user-images.githubusercontent.com/97247515/170107291-64758271-dc33-4086-b3e2-a7493d71ea91.png)
# > * Data Science Summer School from Hertie School Data Science Lab, Berlin, Germany Jul 2021 | [Certificate](https://user-images.githubusercontent.com/97247515/169648006-7e4ecd27-757a-45d3-9f7d-df36637a2ce7.png)
# > * Summer Data Science Boot Camp from Consulting and Analytics Club, IIT Guwahati, India Jun 2021[Certificate](https://user-images.githubusercontent.com/97247515/169647503-8f23a95b-0ea8-4c6b-9486-dec26e364b0f.png)
#
# **Workshops:**
# > * How to build modern data science prototype applications from from Hertie School Data Science Lab, Feb 2022
# > * AI Model in a Notebook to Production from Abacus.AI MLOps | [Certificate](https://user-images.githubusercontent.com/97247515/170102766-b9898068-ff7f-4ddc-a2b6-66f82a08b22a.png)
# > * AI in Drug Discovery from Imperial College Computational Biology Society Feb 2021 | [Certificate](https://user-images.githubusercontent.com/97247515/170103083-a17401cc-da12-48fa-a396-67a1e04e3a04.png)
# > * Indo-German Spring School on Algorithms for Big Data, Feb 2020
# > * Data Science using R from IIIT New Delhi, Dec 2018
#
# **Educations:**
# > * **Post Graduate Diploma** in Biological Data Analytics | School of Computational and Integrative Sciences, JNU | New Delhi, India | July 2019-Aug 2020 with CGPA: 7.32
# > * **Master of Science** in Bioinformatics | University Institute of Engineering and Technology, CSJM University Kanpur | U.P India  | July 2016-June 2018 with CGPA: 7.40
# > * **Bachelor of Science (H)** in Biotech., School of Life Sciences and Technology, AKS University Satna | M.P India | July 2012-June 2015. with CGPA: 6.36
#
# **National Examinations:**
# > * JNUEE M.Tech./PGD-2019 Rank: 02 | Reg No: 1611000144
# > * ICAR-JRF/SRF-2020 Bioinformatics Rank: 37 | Roll No: MP13000207
#
# **References:**
# > * **Prof. Rita Sharma:** Professor, and Thesis Supervisor, Department of Biological Sciences, Birla Institute of Technology and Science, Pilani, Rajasthan,India.**Email:** rita.genomics@gmail.com   **Tel:** +919958312717
# > * **Prof. Shandar Ahmad**, Professor, SCIS-JNU New Delhi, India. **Email:** shandar@jnu.ac.in **Tel:** +917290889021
#
#                                     _._   😷 | 🪴 🏃‍♂️ 🍃 🏋️‍ ⛹️‍ 🧘‍ 🎧 | 🎯 🖥️ 🧬 🦠 🧫 🧪 📊 |🕉️
